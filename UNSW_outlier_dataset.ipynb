# %%
import numpy as np
import pandas as pd
import random
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, export_graphviz

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# https://research.unsw.edu.au/projects/unsw-nb15-dataset

train_original_data = pd.read_csv('/content/drive/MyDrive/dataset/UNSW_NB15_training-set.csv')
# train_original_data = pd.read_csv('UNSW_NB15_training-set.csv')
# test_original_data = pd.read_csv('UNSW_NB15_testing-set.csv')

SIGMA = 0.2
# SAMPLES_RANDOM_TRAIN = 1724*5
# SAMPLES_RANDOM_TEST = 824*5

length = train_original_data.shape[0]

for i in range(train_original_data.shape[0]):
    train_original_data.loc[i, 'label2'] = 1

# for i in range(test_original_data.shape[0]):
#     test_original_data.loc[i, 'label2'] = 1

df = train_original_data
random_indices_train = np.random.choice(df.index, 1724*6, replace = False)

# for index in random_indices_train[:1724]:
#     df_1 = df.iloc[index]

#     rh = df_1['dur']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['dur'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/UNSW_noisy_data/UNSW_noisy_rate_02_1_1.csv')

# for index in random_indices_train[1724:1724*2]:
#     df_1 = df.iloc[index]

#     rh = df_1['rate']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['rate'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/UNSW_noisy_data/UNSW_noisy_rate_02_2_1.csv')

# for index in random_indices_train[1724*2:1724*3]:
#     df_1 = df.iloc[index]

#     rh = df_1['rate']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['rate'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/UNSW_noisy_data/UNSW_noisy_rate_02_3_1.csv')

# for index in random_indices_train[1724*3:1724*4]:
#     df_1 = df.iloc[index]

#     rh = df_1['rate']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['rate'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/UNSW_noisy_data/UNSW_noisy_rate_02_4_1.csv')

# for index in random_indices_train[1724*4:1724*5]:
#     df_1 = df.iloc[index]

#     rh = df_1['rate']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['rate'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/UNSW_noisy_data/UNSW_noisy_rate_02_5_1.csv')

for index in random_indices_train[:1724*6]:
    df_1 = df.iloc[index]

    rh = df_1['dur']

    sigma_RH = SIGMA* rh
    noise_RH = random.gauss(0, sigma_RH)

    rh += noise_RH
    df_1['dur'] = rh
    df_1['label2'] = 0

    length +=1
    df.loc[length] = df_1
    # df.loc[index] = df_1

df.to_csv('/content/drive/MyDrive/dataset/UNSW_noisy_data/UNSW_noisy_dur_02_6_1.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:1056: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cacher_needs_updating = self._check_is_chained_assignment_possible()
