# %%
import numpy as np
import pandas as pd
import random
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split


# https://research.unsw.edu.au/projects/unsw-nb15-dataset

train_original_data = pd.read_csv('/content/drive/MyDrive/dataset/pems2.csv')
# train_original_data = pd.read_csv('UNSW_NB15_training-set.csv')
# test_original_data = pd.read_csv('UNSW_NB15_testing-set.csv')

SIGMA = 0.2
# SAMPLES_RANDOM_TRAIN = 1724*5
# SAMPLES_RANDOM_TEST = 824*5

length = train_original_data.shape[0]

for i in range(train_original_data.shape[0]):
    train_original_data.loc[i, 'label2'] = 1

# for i in range(test_original_data.shape[0]):
#     test_original_data.loc[i, 'label2'] = 1

df = train_original_data
random_indices_train = np.random.choice(df.index, 522*6, replace = False)

# for index in random_indices_train[:522]:
#     df_1 = df.iloc[index]

#     rh = df_1['400017']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['400017'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/PEMS_noisy_data/PEMS_noisy_400017_02_1_1.csv')

# for index in random_indices_train[522:522*2]:
#     df_1 = df.iloc[index]

#     rh = df_1['400017']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['400017'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/PEMS_noisy_data/PEMS_noisy_400017_02_2_1.csv')

# for index in random_indices_train[522*2:522*3]:
#     df_1 = df.iloc[index]

#     rh = df_1['400017']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['400017'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/PEMS_noisy_data/PEMS_noisy_400017_02_3_1.csv')

# for index in random_indices_train[522*3:522*4]:
#     df_1 = df.iloc[index]

#     rh = df_1['400017']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['400017'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/PEMS_noisy_data/PEMS_noisy_400017_02_4_1.csv')

# for index in random_indices_train[522*4:522*5]:
#     df_1 = df.iloc[index]

#     rh = df_1['400017']

#     sigma_RH = SIGMA* rh
#     noise_RH = random.gauss(0, sigma_RH)

#     rh += noise_RH
#     df_1['400017'] = rh
#     df_1['label2'] = 0

#     length +=1
#     df.loc[length] = df_1
#     # df.loc[index] = df_1

# df.to_csv('/content/drive/MyDrive/dataset/PEMS_noisy_data/PEMS_noisy_400017_02_5_1.csv')

for index in random_indices_train[:522*6]:
    df_1 = df.iloc[index]

    rh = df_1['400001']

    sigma_RH = SIGMA* rh
    noise_RH = random.gauss(0, sigma_RH)

    rh += noise_RH
    df_1['400001'] = rh
    df_1['label2'] = 0

    length +=1
    df.loc[length] = df_1
    # df.loc[index] = df_1

df.to_csv('/content/drive/MyDrive/dataset/PEMS_noisy_data/PEMS_noisy_400001_02_6_1.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:1056: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cacher_needs_updating = self._check_is_chained_assignment_possible()
